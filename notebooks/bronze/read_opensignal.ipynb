# %%
# %run ./bronze_pipeline_utils

# %%
ingest_vendor_bronze(
    vendor_name="opensignal",
    file_path="abfss://datalake@attinlapsa.dfs.core.windows.net/vendors/opensignal.csv",
    table_name="inlap.bronze.opensignal",
    date_column_name="measured_at",
    delimiter="|"
)
