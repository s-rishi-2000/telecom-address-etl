# %%
# %run ./bronze_pipeline_utils

# %%
# Call the generic ingestion function for GeoResults (passing its unique date column)
ingest_vendor_bronze(
    vendor_name="georesults",
    file_path="abfss://datalake@attinlapsa.dfs.core.windows.net/vendors/georesults.csv",
    table_name="inlap.bronze.georesults",
    date_column_name="last_touch"  # Change this to whatever date field GeoResults uses
)
