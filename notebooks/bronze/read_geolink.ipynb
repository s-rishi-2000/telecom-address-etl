# %%
# %run ./bronze_pipeline_utils

# %%
ingest_vendor_bronze(
    vendor_name="geolink",
    file_path="abfss://datalake@attinlapsa.dfs.core.windows.net/vendors/geolink.csv",
    table_name="inlap.bronze.geolink",
    date_column_name="last_verified"
)

# %%
# from pyspark.sql.functions import col

# display(
#     spark.table("inlap.bronze.geolink")
#     .orderBy(col("last_verified").desc(), col("glid").asc())
#     .limit(5)
# )
