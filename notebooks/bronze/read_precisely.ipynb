# %%
# %run ./bronze_pipeline_utils

# %%
ingest_vendor_bronze(
    vendor_name="precisely",
    file_path="abfss://datalake@attinlapsa.dfs.core.windows.net/vendors/precisely.csv",
    table_name="inlap.bronze.precisely",
    date_column_name="MOD_DATE",
    date_format="MM/dd/yyyy"
)
