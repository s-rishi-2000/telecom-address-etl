# %%
# %run ./bronze/read_georesults

# %%
# %sql
# SELECT 'bronze.georesults' AS tbl, COUNT(*) AS rows FROM inlap.bronze.georesults
# UNION ALL SELECT 'bronze.heretech', COUNT(*) FROM inlap.bronze.heretech
# UNION ALL SELECT 'bronze.nv5', COUNT(*) FROM inlap.bronze.nv5
# UNION ALL SELECT 'bronze.opensignal', COUNT(*) FROM inlap.bronze.opensignal
# UNION ALL SELECT 'bronze.precisely', COUNT(*) FROM inlap.bronze.precisely
# UNION ALL SELECT 'bronze.geolink', COUNT(*) FROM inlap.bronze.geolink
# UNION ALL SELECT 'silver.georesults_conformed', COUNT(*) FROM inlap.silver.georesults_conformed
# UNION ALL SELECT 'silver.heretech_conformed', COUNT(*) FROM inlap.silver.heretech_conformed
# UNION ALL SELECT 'silver.nv5_conformed', COUNT(*) FROM inlap.silver.nv5_conformed
# UNION ALL SELECT 'silver.opensignal_conformed', COUNT(*) FROM inlap.silver.opensignal_conformed
# UNION ALL SELECT 'silver.precisely_conformed', COUNT(*) FROM inlap.silver.precisely_conformed
# UNION ALL SELECT 'silver.geolink_conformed', COUNT(*) FROM inlap.silver.geolink_conformed
# UNION ALL SELECT 'silver.sites_unified', COUNT(*) FROM inlap.silver.sites_unified
# ORDER BY tbl

# %%
# %sql
# SELECT
#   COUNT(*) AS total_rows,
#   SUM(CASE WHEN site_id IS NULL THEN 1 ELSE 0 END) AS site_id_nulls,
#   SUM(CASE WHEN lat IS NULL THEN 1 ELSE 0 END) AS lat_nulls,
#   SUM(CASE WHEN lon IS NULL THEN 1 ELSE 0 END) AS lon_nulls,
#   SUM(CASE WHEN source_vendor IS NULL THEN 1 ELSE 0 END) AS source_vendor_nulls
# FROM inlap.silver.sites_unified

# %%
# %run ./bronze/read_heretech

# %%
# %run ./bronze/read_nv5

# %%
# %run ./bronze/read_opensignal

# %%
# %run ./bronze/read_precisely

# %%
# %run ./bronze/read_geolink

# %%
# %run ./silver/silver_georesults

# %%
# %run ./silver/silver_heretech

# %%
# %run ./silver/silver_nv5

# %%
# %run ./silver/silver_opensignal

# %%
# %run ./silver/silver_precisely

# %%
# %run ./silver/silver_geolink

# %%
# %run ./silver/silver_entity_resolution
